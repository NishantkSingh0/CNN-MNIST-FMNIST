# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,Conv2D,MaxPooling2D,Flatten
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
(X_train,Y_train),(X_test,Y_test)=tf.keras.datasets.fashion_mnist.load_data()
# Out:
# ...
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
# X_train=X_train/255.0
X_train=np.array(X_train)/255
X_test=np.array(X_test)/255

# %%
model=keras.Sequential([
    Conv2D(32,(3,3),input_shape=(28,28,1),activation='relu'),
    MaxPooling2D((2,2)),
    Conv2D(64,(3,3),activation='relu'),
    MaxPooling2D((2,2)),
    Conv2D(64,(3,3),activation='relu'),
    Flatten(),
    Dense(64,activation='relu'),
    Dense(10,activation='softmax')
])

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=['accuracy']
    )

# %%
model.fit(X_train[...,tf.newaxis],Y_train,epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 48s 25ms/step - loss: 0.4967 - accuracy: 0.8166
# Epoch 2/10
# 1875/1875 [==============================] - 45s 24ms/step - loss: 0.3226 - accuracy: 0.8824
# Epoch 3/10
# 1875/1875 [==============================] - 45s 24ms/step - loss: 0.2766 - accuracy: 0.8994
# Epoch 4/10
# 1875/1875 [==============================] - 44s 24ms/step - loss: 0.2468 - accuracy: 0.9082
# Epoch 5/10
# 1875/1875 [==============================] - 45s 24ms/step - loss: 0.2235 - accuracy: 0.9172
# Epoch 6/10
# 1875/1875 [==============================] - 44s 23ms/step - loss: 0.2030 - accuracy: 0.9252
# Epoch 7/10
# 1875/1875 [==============================] - 44s 24ms/step - loss: 0.1848 - accuracy: 0.9306
# Epoch 8/10
# 1875/1875 [==============================] - 44s 24ms/step - loss: 0.1707 - accuracy: 0.9360
# Epoch 9/10
# 1875/1875 [==============================] - 44s 23ms/step - loss: 0.1587 - accuracy: 0.9410
# Epoch 10/10
# ...

# %%
K=model.predict(X_test)
# Out:
# 313/313 [==============================] - 2s 7ms/step

# %%
Arr=['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
i=0
while True:
  i=int(input("Enter index: "))
  if i==-1:
    print("Exited")
    break
  elif i>=10000:
    print("Index out of range...")
    break
  plt.imshow(X_test[i],cmap='gray')
  plt.show()
  print(f"Predicted: {Arr[np.argmax(K[i])]}")
  print(f"Actual: {Arr[Y_test[i]]}")
# Out:
# Enter index: 10000
# Index out of range...

# %%
model.save("CNN_fashion_mnist_model.h5")
from google.colab import files
files.download("CNN_fashion_mnist_model.h5")
